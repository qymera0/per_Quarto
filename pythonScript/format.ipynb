# %% [raw]
# ---
# title: "Quarto Document"
# author: "Norah Jones"
# toc: true
# number-sections: true
# highlight-style: pygments
# format:
#   html:
#     code-fold: true
#     html-math-method: katex
#   pdf:
#     geometry:
#       - top=30mm
#       - left=30mm
#   docx: default
# ---

# %% [markdown]
# ## Colors
# - Red
# - Green
# - Blue

# %% [markdown]
# ## Shapes
# - Square
# - Circle
# - Triangle

# %% [markdown]
# ## Textures
# - Smooth
# - Bumpy
# - Fuzzy

# %% [markdown]
# $E = mc^{2}$

# %% [markdown]
# See @fig-simple in @sec-plot for a demonstration of simple plot.
# See @eq-stddev to better understand standard deviation

# %% [markdown]
# ## Plot {#sec-plot}

# %%
#| label: fig-simple
#| fig-cap: Simple plot

import matplotlib.pyplot as plt
plt.plot([1, 23, 2, 4])
plt.show()

# %% [markdown]
# ## Equation {#sec-equation}
#
# $$
# s = \sqrt{\frac{1}{N-1} \sum_{i=1}^N (x_i - \overline{x})^2}
# $$ {#eq-stddev}

# %% [markdown]
# ::: {.callout-note}
# Note that there are five types of callouts, including:
# 'note', 'tip', 'warning', 'caution', and 'important'.
# :::
